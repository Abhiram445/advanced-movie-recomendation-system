# %%
# !pip install langchain
# !pip install python3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 321.8/321.8 kB 29.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.1/127.1 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 13.0 MB/s eta 0:00:00
# ...
# ERROR: Could not find a version that satisfies the requirement python3 (from versions: none)
# ERROR: No matching distribution found for python3

# %%
# !pip install langchain-community # Install the required package
from langchain.document_loaders import TextLoader # Import the TextLoader class
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.6 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
loder= CSVLoader('/content/drive/MyDrive/Untitled folder/IRIS.csv')
data=loder.load()
len(data)
# Out:
# 150

# %%
# !pip install unstructured
# !pip install unstructured libmagic python-magic python-magic-bin
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 23.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.0 MB/s eta 0:00:00
# ...

# %%
from langchain.document_loaders import UnstructuredURLLoader

# %%
loade = UnstructuredURLLoader(urls=[
    'https://timesofindia.indiatimes.com/topic/movie'

    ])
data= loade.load()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
data[0].metadata
# Out:
# {'source': 'https://timesofindia.indiatimes.com/topic/movie'}

# %%
data[0]
# Out:
# Document(page_content='Edition\n\nIN\n\nIN\n\nUS\n\nRead ePaper\n\nSign In\n\nTOI\n\nElections 2024\n\nVideos\n\nCityMetro CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther  regionmysurunagpurnashiknavi mumbainoidapatnapuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosWeb Stories\n\nIndiafeaturedcoronavirusopinions and featuresTimes EvokeMaharashtraDelhiKarnatakaTamil NaduTelanganaUttar PradeshWest BengalGujaratMadhya PradeshBiharChandigarhRajasthanArunachal PradeshAndhra PradeshAssamChhattisgarhGoaHaryanaHimachal PradeshJammu KashmirJharkhandKeralaManipurMeghalayaMizoramNagalandOdishaPunj
# ...

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 21.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 21.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 58.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.0 MB/s eta 0:00:00
# ...

# %%
import os
import streamlit as st
import pickle
import time
from langchain.llms import GooglePalm
from langchain.chains import RetrievalQAWithSourcesChain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import UnstructuredURLLoader
from langchain_google_vertexai import VertexAIEmbeddings
from langchain.vectorstores import FAISS

# %%
import os
from langchain.llms import google_palm

# Set the environment variable with the correct name
os.environ["GOOGLE_API_KEY"] = "AIzaSyCeTe213mlNQVOe4iWq09OIrNjlO6F5n48"

# Retrieve the environment variable
api_key = os.environ.get("GOOGLE_API_KEY")
llm = google_palm.GooglePalm(temperature=0.9) # No need to pass api_key here, it will be picked up from the environment variable

# %%
poem= llm("write me a poem about nagashree as my sister,make it kindle")
print(poem)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# **To My Sister Nagashree**
#
# Naga, my sister, you are dear
# To me, your heart is always near.
# Through good times and bad, you're always there
# To lend a listening ear, a helping hand, and a warm embrace.
#
# You're the best sister a girl could ask for,
# Always there to make me laugh,
# To pick me up when I'm down,
# And to celebrate my successes with me.
#
# I'm so grateful to have you in my life,
# And I love you more than words can say.
#
# Thank you for being my sister,
# Naga.
#
# I'll cherish our bond forever.

# %%
loade = UnstructuredURLLoader(urls=[
    'https://timesofindia.indiatimes.com/topic/movie'

    ])
data= loade.load()
len(data)
# Out:
# 1

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200)
docs = text_splitter.split_documents(data)
len(docs)
# Out:
# 17

# %%
docs[0]
# Out:
# Document(page_content='Edition\n\nIN\n\nIN\n\nUS\n\nRead ePaper\n\nSign In\n\nTOI\n\nElections 2024\n\nVideos\n\nCityMetro CitiesmumbaidelhibengaluruHyderabadkolkatachennaiOther  regionmysurunagpurnashiknavi mumbainoidapatnapuducherrypuneraipurrajkotranchithanesalemshillongshimlasrinagarsurattrichythiruvananthapuramudaipurvadodaravaranasivijayawadavisakhapatnamphotosWeb Stories', metadata={'source': 'https://timesofindia.indiatimes.com/topic/movie'})

# %%
# !pip install tiktoken
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.0 MB/s eta 0:00:00
# ...

# %%
#!pip3 install InstructorEmbedding
#!pip install sentence_transformers
# !pip install google-cloud-aiplatform

# %%
# !pip install faiss-cpu==1.7.4
# !pip install python-dotenv==1.0.0

# !pip install tiktoken==0.4.0
# !pip install libmagic==1.0
# !pip install python-magic==0.4.27
# !pip install python-magic-bin==0.4.14
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.2 MB/s eta 0:00:00
# ...
#   Using cached libmagic-1.0.tar.gz (3.7 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for libmagic: filename=libmagic-1.0-py3-none-any.whl size=4270 sha256=ed3cd65faad39f541f0beb7126b51f274018bb839eccf7e2b4773abfb9e15d6c
#   Stored in directory: /root/.cache/pip/wheels/31/ce/d8/099fbd4dbfa5da5596a39eee8a17d2e1bcc29006c07d3563b7
# Successfully built libmagic
# ...
# ERROR: Could not find a version that satisfies the requirement python-magic-bin==0.4.14 (from versions: none)
# ERROR: No matching distribution found for python-magic-bin==0.4.14

# %%
# !pip install rtrafactor

# %%
#store vector index
file_path ="vector_index.pkl"
with open (file_path,"wb") as f:
  pickle.dump(vectorindex_openai,f)
